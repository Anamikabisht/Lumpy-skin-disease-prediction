# %% [markdown]
# <a href="https://colab.research.google.com/github/Anamikabisht/Lumpy-skin-disease-prediction/blob/main/Lumpy_skin_disease_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
lumpy_dataset=pd.read_csv(r"/content/archieve.csv")
lumpy_dataset.head()
# Out:
#            x          y region     country reportingDate   cld   dtr    frs  \
# 0  90.380931  22.437184   Asia  Bangladesh     10/9/2020  41.6  12.8   0.00
# 1  87.854975  22.986757   Asia       India    20/12/2019  40.5  13.3   0.00
# 2  85.279935  23.610181   Asia       India    20/12/2019  27.3  13.6   0.08
# 3  81.564510  43.882221   Asia       China    25/10/2019  45.3  12.8  31.00
# 4  81.161057  43.834976   Asia       China    25/10/2019  38.8  13.2  31.00
#
#    pet   pre   tmn   tmp   tmx   vap   wet  elevation  dominant_land_cover  \
# 0  2.3   1.7  12.7  19.1  25.5  15.7  0.00        147                    2
# 1  2.4   0.0  13.2  19.8  26.5  16.3  0.00        145                    2
# 2  2.3   0.6   9.4  16.2  23.0  13.0  0.98        158                    2
# 3  0.4   8.8 -22.5 -16.1  -9.7   0.9  4.64        178                    2
# 4  0.4  10.5 -20.4 -13.8  -7.2   1.2  1.69        185                    3
#
#    X5_Ct_2010_Da  X5_Bf_2010_Da  lumpy
# ...

# %%
#Droping the columns having string data as they are not necessary and only numerical values will be needed for further calculation
lumpy_dataset=lumpy_dataset.drop(['region','country','reportingDate'],axis=1)
lumpy_dataset.head()
# Out:
#            x          y   cld   dtr    frs  pet   pre   tmn   tmp   tmx   vap  \
# 0  90.380931  22.437184  41.6  12.8   0.00  2.3   1.7  12.7  19.1  25.5  15.7
# 1  87.854975  22.986757  40.5  13.3   0.00  2.4   0.0  13.2  19.8  26.5  16.3
# 2  85.279935  23.610181  27.3  13.6   0.08  2.3   0.6   9.4  16.2  23.0  13.0
# 3  81.564510  43.882221  45.3  12.8  31.00  0.4   8.8 -22.5 -16.1  -9.7   0.9
# 4  81.161057  43.834976  38.8  13.2  31.00  0.4  10.5 -20.4 -13.8  -7.2   1.2
#
#     wet  elevation  dominant_land_cover  X5_Ct_2010_Da  X5_Bf_2010_Da  lumpy
# 0  0.00        147                    2   27970.983100    3691.746950      1
# 1  0.00        145                    2   25063.646690     671.326701      1
# 2  0.98        158                    2    6038.477155    1426.839831      1
# 3  4.64        178                    2     760.703340       0.000000      1
# 4  1.69        185                    3     270.367426       0.000000      1

# %%
#number of rows and co;umns in this dataset
lumpy_dataset.shape
# Out:
# (24803, 17)

# %%
#getting the statistical measures of data
lumpy_dataset.describe()
# Out:
#                   x             y           cld           dtr           frs  \
# count  24803.000000  24803.000000  24803.000000  24803.000000  24803.000000
# mean      79.221374     46.370056     59.452159      9.107777     23.978048
# std       43.338530     19.220555     19.423029      2.988448     11.518315
# min     -179.750000    -28.750000      0.000000      2.000000      0.000000
# 25%       45.083150     34.750000     43.800000      6.800000     23.210000
# 50%       80.750000     48.250000     62.300000      8.300000     31.000000
# 75%      109.750000     61.750000     75.300000     11.100000     31.000000
# max      179.750000     81.750000     98.700000     20.600000     31.000000
#
#                 pet           pre           tmn           tmp           tmx  \
# count  24803.000000  24803.000000  24803.000000  24803.000000  24803.000000
# mean       0.803487     26.271137    -15.794755    -11.227807     -6.681212
# ...

# %%
lumpy_dataset['lumpy'].value_counts()
# Out:
# lumpy
# 0    21764
# 1     3039
# Name: count, dtype: int64

# %% [markdown]
# 0--->healthy cows 1--->infected cows

# %%
lumpy_dataset.groupby('lumpy').mean()
# Out:
#                x          y        cld       dtr        frs       pet  \
# lumpy
# 0      85.835232  47.422785  57.726594  9.349265  24.721930  0.776424
# 1      31.855785  38.830861  71.809905  7.378348  18.650684  0.997302
#
#              pre        tmn        tmp       tmx       vap        wet  \
# lumpy
# 0      20.997041 -17.822602 -13.133119 -8.469367  3.414726   8.311494
# 1      64.041922  -1.272195   2.417210  6.124778  5.973412  10.196716
#
#         elevation  dominant_land_cover  X5_Ct_2010_Da  X5_Bf_2010_Da
# lumpy
# 0      165.595892             4.562718     570.463555     186.704273
# 1      158.849622             3.366239    1049.268834      52.869146

# %%
#separating data and labels
x = lumpy_dataset.drop(columns = 'lumpy',axis=1)
y = lumpy_dataset['lumpy']

# %%
print(x)
# Out:
#                x          y   cld   dtr    frs  pet    pre   tmn   tmp   tmx  \
# 0      90.380931  22.437184  41.6  12.8   0.00  2.3    1.7  12.7  19.1  25.5
# 1      87.854975  22.986757  40.5  13.3   0.00  2.4    0.0  13.2  19.8  26.5
# 2      85.279935  23.610181  27.3  13.6   0.08  2.3    0.6   9.4  16.2  23.0
# 3      81.564510  43.882221  45.3  12.8  31.00  0.4    8.8 -22.5 -16.1  -9.7
# 4      81.161057  43.834976  38.8  13.2  31.00  0.4   10.5 -20.4 -13.8  -7.2
# ...          ...        ...   ...   ...    ...  ...    ...   ...   ...   ...
# 24798  20.250000 -16.750000  68.8  12.0   0.00  3.6  172.0  17.7  23.7  29.7
# 24799  20.750000 -16.750000  68.8  11.8   0.00  3.6  170.0  18.0  23.9  29.8
# 24800  21.250000 -16.750000  68.8  11.6   0.00  3.6  167.5  18.3  24.1  29.9
# 24801  21.750000 -16.750000  68.8  11.5   0.00  3.6  169.5  18.5  24.2  30.0
# 24802  22.250000 -16.750000  67.5  11.4   0.00  3.7  172.1  18.7  24.4  30.1
#
# ...

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
standardized_data = scaler.transform(x)
scaler.fit(standardized_data)
# Out:
# StandardScaler()

# %%
print(standardized_data)
# Out:
# [[ 0.25750256 -1.24519576 -0.91914186 ... -1.00412974 11.99649859
#    3.12196955]
#  [ 0.19921708 -1.2166022  -0.97577681 ... -1.00412974 10.72087706
#    0.44418499]
#  [ 0.13979901 -1.18416627 -1.65539615 ... -1.00412974  2.37340282
#    1.11399291]
#  ...
#  [-1.33766749 -3.2840533   0.48128587 ...  0.24265868 -0.22788999
#   -0.15098658]
#  [-1.32613018 -3.2840533   0.48128587 ... -0.5885336  -0.2305137
#   -0.15098658]
#  [-1.31459287 -3.2840533   0.41435367 ... -0.5885336  -0.23870482
#   -0.15098658]]

# %%
x = standardized_data
y = lumpy_dataset['lumpy']

# %%
print(x)
print(y)
# Out:
# [[ 0.25750256 -1.24519576 -0.91914186 ... -1.00412974 11.99649859
#    3.12196955]
#  [ 0.19921708 -1.2166022  -0.97577681 ... -1.00412974 10.72087706
#    0.44418499]
#  [ 0.13979901 -1.18416627 -1.65539615 ... -1.00412974  2.37340282
#    1.11399291]
#  ...
#  [-1.33766749 -3.2840533   0.48128587 ...  0.24265868 -0.22788999
#   -0.15098658]
#  [-1.32613018 -3.2840533   0.48128587 ... -0.5885336  -0.2305137
#   -0.15098658]
#  [-1.31459287 -3.2840533   0.41435367 ... -0.5885336  -0.23870482
#   -0.15098658]]
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 24798    0
# 24799    0
# 24800    0
# 24801    0
# 24802    0
# Name: lumpy, Length: 24803, dtype: int64

# %% [markdown]
# Train Test Split

# %%
x_train, x_test ,y_train, y_test = train_test_split(x,y,test_size = 0.2 , stratify=y, random_state=2)

# %%
print(x.shape, x_train.shape,x_test.shape)
# Out:
# (24803, 16) (19842, 16) (4961, 16)

# %% [markdown]
# Training the model

# %%
classifier = svm.SVC(kernel='linear')

# %%
#training the support vector machine classifier
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
#Accuracy score on training data
x_train_prediction = classifier.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy score of training data : ',training_data_accuracy)
# Out:
# Accuracy score of training data 0.9471827436750327

# %%
#Accuracy score on testing data
x_test_prediction = classifier.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy score of testing data : ',test_data_accuracy)
# Out:
# Accuracy score of testing data :  0.941544043539609

# %% [markdown]
# Making a Predictive System

# %%
input_data = (36.1637,35.6116,71.6,6,4.45,1.4,140.1,5.5,8.5,11.5,7.8,18.11,197,2,902.3791892,0)
# Changing the input into a numpy array
input_data_as_numpyArray = np.asarray(input_data)

# Reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpyArray.reshape(1, -1)

# Standardize the input data
standard_data = scaler.transform(input_data_reshaped)
print(standard_data)

prediction = classifier.predict(standard_data)
print(prediction)

if(prediction[0]==1):
 print("Lumpy infected cow")
else:
 print("Healthy cow" )
# Out:
# [[3.61637000e+01 3.56116000e+01 7.16000000e+01 6.00000000e+00
#   4.45000000e+00 1.40000000e+00 1.40100000e+02 5.50000000e+00
#   8.50000000e+00 1.15000000e+01 7.80000000e+00 1.81100000e+01
#   1.97000000e+02 2.00000000e+00 9.02379189e+02 2.97933494e-17]]
# [1]
# Lumpy infected cow
